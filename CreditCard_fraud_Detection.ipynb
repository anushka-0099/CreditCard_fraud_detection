# %%
# !pip install kaggle==1.5.12
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73026 sha256=493c3cf084f57a1e66b6202a21abc9fb6621ee3d96d7c1e54c836822fbd96e4e
#   Stored in directory: /root/.cache/pip/wheels/2e/27/39/f44e52756a6407b444143f233abe9fda0e18a23e8b20e0cd1c
# Successfully built kaggle
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.7.4.2
#     Uninstalling kaggle-1.7.4.2:
#       Successfully uninstalled kaggle-1.7.4.2
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !ls
# Out:
# sample_data

# %%
# !chmod 600 /kaggle/kaggle.json

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
# The file path should include the file name and extension,
# and it should correspond to a file available in the dataset.
# For example, if the dataset contains a CSV file named 'creditcard.csv',
# you would set file_path to 'creditcard.csv'.
file_path = "creditcard.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "mlg-ulb/creditcardfraud",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# <ipython-input-54-77a967de6444>:14: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df = kagglehub.load_dataset(
# First 5 records:    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
class_count=df['Class'].value_counts()
val=[0,1]
plt.figure(figsize=(8, 6))
plt.bar((0,1), class_count)
plt.title('Count Plot of class label')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
class_count
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# this shows the imbalanced class labels which will create a model which will not perform well on the unobserved inputs, so we need to balance this out

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('Class',axis=1),df['Class'],test_size=0.3,random_state=0)

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train)

# %%
count_new=y_resampled.value_counts()

# %%
count_new
# Out:
# Class
# 0    345
# 1    345
# Name: count, dtype: int64

# %%
X_train.shape
# Out:
# (199364, 30)

# %%
X_resampled.shape
# Out:
# (690, 30)

# %%
import pandas as pd
matrix = df.corr()
plt.figure(figsize=(30,12))
# plotting correlation matrix
sns.heatmap(matrix, cmap="Greens", annot=True)
plt.show()

# %%
df_n
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#as we can see from correlation matrix that time has no effect(almost 0) on class which is target, so we drop this
X_resampled.drop('Time',axis=1,inplace=True)
X_test.drop('Time',axis=1,inplace=True)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
#scaling all
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_resampled=scaler.fit_transform(X_resampled)
X_test=scaler.transform(X_test)

# %%
X_resampled
# Out:
# array([[ 0.30769177, -0.40969467,  0.77710581, ...,  0.03820335,
#          0.19944935,  0.55486968],
#        [ 0.00622121, -0.92058615,  0.89978108, ..., -0.46558313,
#         -1.90925371,  0.05708862],
#        [ 0.53216157, -0.38302763,  0.36714812, ..., -0.07568765,
#         -0.19215364, -0.45756638],
#        ...,
#        [-0.55084186, -0.33940535, -0.43076818, ...,  1.38079203,
#          0.76592628, -0.49553273],
#        [-1.39758659,  1.05234915, -1.27454681, ...,  0.22790557,
#         -0.47895387, -0.49975121],
#        [-0.06099423, -0.09256342,  0.08794985, ...,  1.38518073,
#         -0.8963383 ,  5.21313014]])

# %%
#now model is ready
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
#since it is classification task so we will apply classification algo's
#1)logistic regression
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression()
model1.fit(X_resampled,y_resampled)
# Out:
# LogisticRegression()

# %%
y_pred1=model1.predict(X_test)

# %%
acc_1=accuracy_score(y_test,y_pred1)

# %%
acc_1
# Out:
# 0.9780672495113701

# %%
class_rep1=classification_report(y_test,y_pred1)

# %%
print(class_rep1)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85296
#            1       0.07      0.89      0.12       147
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.93      0.56     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
cm1=confusion_matrix(y_test,y_pred1)

# %%
print(cm1)
# Out:
# [[83438  1858]
#  [   16   131]]

# %%
X_test.shape
# Out:
# (85443, 29)

# %%
X_resampled.shape
# Out:
# (690, 29)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
m2=RandomForestClassifier()

# %%
m2.fit(X_resampled,y_resampled)
# Out:
# RandomForestClassifier()

# %%
y_2pred=m2.predict(X_test)

# %%
accu2=accuracy_score(y_test,y_2pred)
accu2
# Out:
# 0.9829593998338073

# %%
cm2=confusion_matrix(y_test,y_2pred)
print(cm2)
# Out:
# [[83856  1440]
#  [   16   131]]

# %%
from sklearn.ensemble import GradientBoostingClassifier
m3=GradientBoostingClassifier()
m3.fit(X_resampled,y_resampled)
y_3=m2.predict(X_test)

# %%
acc_3=accuracy_score(y_test,y_3)

# %%
acc_3
# Out:
# 0.9829593998338073
